# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Health.csv")
df
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 1         1002              Jane Doe   62  Female         B-       Diabetes
# 2         1003        Robert Johnson   35    Male         O+         Cancer
# 3         1004          Susan Wilson   78  Female         A-  Heart Disease
# 4         1005         Michael Brown   55    Male        AB+         Asthma
# 5         1006           Lisa Miller   30  Female         B+   Hypertension
# 6         1007           James Davis   48    Male         O-       Diabetes
# 7         1008          Karen Harris   65  Female        AB-         Cancer
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 9         1010           Linda Smith   42  Female         O+         Asthma
# 10        1011           William Lee   33    Male        AB+   Hypertension
# ...

# %%
plt.hist(df['Age'])
# Out:
# (array([4., 5., 8., 7., 6., 7., 5., 4., 3., 1.]),
#  array([29. , 33.9, 38.8, 43.7, 48.6, 53.5, 58.4, 63.3, 68.2, 73.1, 78. ]),
#  <BarContainer object of 10 artists>)

# %%
df['Gender'].describe()
# Out:
# count       50
# unique       2
# top       Male
# freq        25
# Name: Gender, dtype: object

# %% [markdown]
# 50% of the patients are Male

# %%
df.groupby(['Diagnosis']).count()
# Out:
#                Patient_ID  Patient_Name  Age  Gender  Blood_Type  \
# Diagnosis
# Asthma                 10            10   10      10          10
# Cancer                 10            10   10      10          10
# Diabetes               10            10   10      10          10
# Heart Disease          10            10   10      10          10
# Hypertension           10            10   10      10          10
#
#                Treatment_Cost
# Diagnosis
# Asthma                      7
# Cancer                      6
# Diabetes                    7
# Heart Disease               8
# Hypertension                6

# %% [markdown]
# There are 10 patients diagnosed with cancer

# %%
df2 = df.loc[df['Age']>60]
df2
# Out:
#     Patient_ID      Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 1         1002          Jane Doe   62  Female         B-       Diabetes
# 3         1004      Susan Wilson   78  Female         A-  Heart Disease
# 7         1008      Karen Harris   65  Female        AB-         Cancer
# 8         1009      David Wilson   72    Male         A+  Heart Disease
# 11        1012        Mary Brown   70  Female         B-         Cancer
# 15        1016      Linda Wilson   62  Female         A+         Cancer
# 18        1019  Michael Williams   67    Male        AB+  Heart Disease
# 31        1032    Linda Martinez   65  Female         B+       Diabetes
# 33        1034         Sarah Lee   70  Female         A-  Heart Disease
# 38        1039     Richard Davis   62    Male         O-  Heart Disease
# 45        1046  Elizabeth Wilson   64  Female         O-   Hypertension
#
#     Treatment_Cost
# 1           800.75
# 3          2700.25
# 7              NaN
# 8          3200.00
# ...

# %%
df2['Treatment_Cost'].mean()
# Out:
# 2553.785714285714

# %% [markdown]
# The mean of the Treatment costs of patients equal to and older than 60 is 2553.78

# %%
df.groupby(['Blood_Type']).mean('Treatment_Cost')
# Out:
#              Patient_ID        Age  Treatment_Cost
# Blood_Type
# A+          1025.500000  53.750000     3594.500000
# A-          1023.833333  58.333333     1470.300000
# AB+         1025.142857  47.714286     2232.687500
# AB-         1028.400000  49.200000     1923.833333
# B+          1024.800000  44.200000      860.250000
# B-          1024.000000  56.600000      860.750000
# O+          1025.250000  43.375000     2870.125000
# O-          1027.333333  48.000000     1935.250000

# %% [markdown]
# The bloodtype with the highest average treatment cost was type A+

# %%
df.groupby(['Gender', 'Diagnosis']).mean('Age')
# Out:
#                        Patient_ID        Age  Treatment_Cost
# Gender Diagnosis
# Female Asthma         1027.333333  47.666667      455.375000
#        Cancer         1025.000000  55.333333     6350.250000
#        Diabetes       1023.200000  54.400000      840.416667
#        Heart Disease  1026.500000  57.750000     2867.083333
#        Hypertension   1028.500000  45.250000     1125.250000
# Male   Asthma         1027.500000  49.000000      450.166667
#        Cancer         1025.500000  44.500000     5950.000000
#        Diabetes       1026.200000  52.000000      912.875000
#        Heart Disease  1026.666667  54.666667     2980.150000
#        Hypertension   1020.333333  39.166667     1256.250000
